# %%
import requests as req

from bs4 import BeautifulSoup as bs

import pandas as pd

from selenium import webdriver

import time

from selenium.webdriver.chrome.options import Options

from webdriver_manager.chrome import ChromeDriverManager

from selenium.webdriver.common.by import By

# %%
#driver configuration
opciones=Options()

opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
opciones.add_experimental_option('useAutomationExtension', False)
opciones.headless=False    # si True, no aperece la ventana (headless=no visible)
opciones.add_argument('--start-maximized')         # comienza maximizado
#opciones.add_argument('user-data-dir=selenium')    # mantiene las cookies
#opciones.add_extension('driver_folder/adblock.crx')       # adblocker
opciones.add_argument('--incognito')

# %%
PATH = ChromeDriverManager().install()  # instala driver de chrome

driver = webdriver.Chrome(PATH)
# Out:
# C:\Users\delbr\AppData\Local\Temp\ipykernel_10432\80690329.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(PATH)

# %%
url = 'https://fbref.com/en/squads/97d1aa04/2022/Spain-Women-Stats'

# %%
driver.get(url)

# %% [markdown]
# # DataFrame estadisticas Eurocopa todas las Jugadoras

# %%
euro_stats = pd.read_csv("C:\\Users\\delbr\\Desktop\\Proyectos IronHack\\PROYECTO_FINAL\\approach2\\data\\Eurocopa\\stats_eurocopa.csv")

# %%
euro_stats
# Out:
#                   Player Pos   Age  MP  Starts  Min  90s  Gls  Ast  G+A  ...  \
# 0             Ona Batlle  DF  22.0   4       4  390  4.3    0  0.0    0  ...
# 1      Patricia Guijarro  MF  23.0   4       4  390  4.3    0  0.0    0  ...
# 2              Mapi León  DF  26.0   4       4  390  4.3    0  2.0    2  ...
# 3           Sandra Paños  GK  29.0   4       4  390  4.3    0  0.0    0  ...
# 4          Irene Paredes  DF  30.0   4       4  390  4.3    1  0.0    1  ...
# 5         Aitana Bonmatí  MF  24.0   4       4  378  4.2    1  0.0    1  ...
# 6      Mariona Caldentey  MF  25.0   4       4  362  4.0    1  1.0    2  ...
# 7          Leila Ouahabi  DF  28.0   3       3  195  2.2    0  0.0    0  ...
# 8           Lucía García  FW  23.0   3       3  191  2.1    1  0.0    1  ...
# 9        Esther González  FW  29.0   3       2  199  2.2    1  0.0    1  ...
# 10         Sheila García  MF  24.0   4       2  188  2.1    0  0.0    0  ...
# ...

# %%
euro_stats = euro_stats.iloc[:, :-1]

euro_stats
# Out:
#                   Player Pos   Age  MP  Starts  Min  90s  Gls  Ast  G+A  ...  \
# 0             Ona Batlle  DF  22.0   4       4  390  4.3    0  0.0    0  ...
# 1      Patricia Guijarro  MF  23.0   4       4  390  4.3    0  0.0    0  ...
# 2              Mapi León  DF  26.0   4       4  390  4.3    0  2.0    2  ...
# 3           Sandra Paños  GK  29.0   4       4  390  4.3    0  0.0    0  ...
# 4          Irene Paredes  DF  30.0   4       4  390  4.3    1  0.0    1  ...
# 5         Aitana Bonmatí  MF  24.0   4       4  378  4.2    1  0.0    1  ...
# 6      Mariona Caldentey  MF  25.0   4       4  362  4.0    1  1.0    2  ...
# 7          Leila Ouahabi  DF  28.0   3       3  195  2.2    0  0.0    0  ...
# 8           Lucía García  FW  23.0   3       3  191  2.1    1  0.0    1  ...
# 9        Esther González  FW  29.0   3       2  199  2.2    1  0.0    1  ...
# 10         Sheila García  MF  24.0   4       2  188  2.1    0  0.0    0  ...
# ...

# %%
euro_stats.to_csv(r'C:\Users\delbr\Desktop\Proyectos IronHack\PROYECTO_FINAL\approach2\data\Eurocopa\stats_euro_jugadoras.csv', index = False)

# %% [markdown]
# # DataFrame estadisticas Mundial todas las jugadoras

# %%
mundial_stats = pd.read_csv("C:\\Users\\delbr\\Desktop\\Proyectos IronHack\\PROYECTO_FINAL\\approach2\\data\\Mundial\\stats_mundial.csv")

mundial_stats
# Out:
#                   Player Pos   Age  MP  Starts  Min  90s  Gls  Ast  G+A  ...  \
# 0          Irene Paredes  DF  31.0   7       7  660  7.3    0    0    0  ...
# 1       Jennifer Hermoso  MF  33.0   7       7  646  7.2    3    2    5  ...
# 2             Ona Batlle  DF  24.0   7       7  612  6.8    0    1    1  ...
# 3       Teresa Abelleira  MF  23.0   7       7  600  6.7    1    1    2  ...
# 4         Aitana Bonmatí  MF  25.0   7       7  582  6.5    3    2    5  ...
# 5       Salma Paralluelo  FW  19.0   7       5  459  5.1    2    0    2  ...
# 6      Mariona Caldentey  FW  27.0   6       5  448  5.0    1    1    2  ...
# 7           Olga Carmona  DF  23.0   6       5  435  4.8    2    0    2  ...
# 8           Alba Redondo  FW  26.0   7       4  393  4.4    3    1    4  ...
# 9              Cata Coll  GK  22.0   4       4  390  4.3    0    0    0  ...
# 10           Laia Codina  DF  23.0   4       4  328  3.6    1    0    1  ...
# ...

# %%
mundial_stats = mundial_stats.iloc[:, :-1]

mundial_stats
# Out:
#                   Player Pos   Age  MP  Starts  Min  90s  Gls  Ast  G+A  ...  \
# 0          Irene Paredes  DF  31.0   7       7  660  7.3    0    0    0  ...
# 1       Jennifer Hermoso  MF  33.0   7       7  646  7.2    3    2    5  ...
# 2             Ona Batlle  DF  24.0   7       7  612  6.8    0    1    1  ...
# 3       Teresa Abelleira  MF  23.0   7       7  600  6.7    1    1    2  ...
# 4         Aitana Bonmatí  MF  25.0   7       7  582  6.5    3    2    5  ...
# 5       Salma Paralluelo  FW  19.0   7       5  459  5.1    2    0    2  ...
# 6      Mariona Caldentey  FW  27.0   6       5  448  5.0    1    1    2  ...
# 7           Olga Carmona  DF  23.0   6       5  435  4.8    2    0    2  ...
# 8           Alba Redondo  FW  26.0   7       4  393  4.4    3    1    4  ...
# 9              Cata Coll  GK  22.0   4       4  390  4.3    0    0    0  ...
# 10           Laia Codina  DF  23.0   4       4  328  3.6    1    0    1  ...
# ...

# %%
mundial_stats.to_csv(r'C:\Users\delbr\Desktop\Proyectos IronHack\PROYECTO_FINAL\approach2\data\Eurocopa\stats_mundial_jugadoras.csv', index = False)

# %%
mundial_stats.T
# Out:
#                        0                 1           2                 3   \
# Player      Irene Paredes  Jennifer Hermoso  Ona Batlle  Teresa Abelleira
# Pos                    DF                MF          DF                MF
# Age                  31.0              33.0        24.0              23.0
# MP                      7                 7           7                 7
# Starts                  7                 7           7                 7
# Min                   660               646         612               600
# 90s                   7.3               7.2         6.8               6.7
# Gls                     0                 3           0                 1
# Ast                     0                 2           1                 1
# G+A                     0                 5           1                 2
# G-PK                    0                 3           0                 1
# PK                      0                 0           0                 0
# ...
