# %%
import pandas as pd

# %%
import warnings

warnings.filterwarnings('ignore')

import bar_chart_race as bcr

# %%
ruta = r"C:\Users\delbr\Desktop\Proyectos IronHack\PROYECTO_FINAL\data\general\victorias evolutivo.xlsx"

data = pd.read_excel(ruta)

data
# Out:
#         Unnamed: 0  2023-07-20 00:00:00  2023-07-21 00:00:00  \
# 0           España                    0                    1
# 1            Japon                    0                    0
# 2          Holanda                    0                    0
# 3          Francia                    0                    0
# 4        Australia                    1                    1
# 5           Suecia                    0                    0
# 6       Inglaterra                    0                    0
# 7         Alemania                    0                    0
# 8          Noruega                    0                    0
# 9        Sudafrica                    0                    0
# 10          Brasil                    0                    0
# 11        Colombia                    0                    0
# 12  Estados Unidos                    0                    0
# 13          Italia                    0                    0
# ...

# %%
data = data.T

data
# Out:
#                          0      1        2        3          4       5   \
# Unnamed: 0           España  Japon  Holanda  Francia  Australia  Suecia
# 2023-07-20 00:00:00       0      0        0        0          1       0
# 2023-07-21 00:00:00       1      0        0        0          1       0
# 2023-07-22 00:00:00       1      1        0        0          1       0
# 2023-07-23 00:00:00       1      1        1        0          1       1
# 2023-07-24 00:00:00       1      1        1        0          1       1
# 2023-07-25 00:00:00       1      1        1        0          1       1
# 2023-07-26 00:00:00       2      2        1        0          1       1
# 2023-07-27 00:00:00       2      2        1        0          1       1
# 2023-07-28 00:00:00       2      2        1        0          1       1
# 2023-07-29 00:00:00       2      2        1        1          1       2
# 2023-07-30 00:00:00       2      2        1        1          1       2
# ...

# %%
data = data.rename(columns={0: 'España', 1: 'Japon', 2: 'Holanda', 3: 'Francia', 4: 'Australia',
                           5: 'Suecia', 6: 'Inglaterra', 7: 'Alemania', 8: 'Noruega',
                           9: 'Sudafrica', 10: 'Brasil', 11: 'Colombia', 12: 'Estados Unidos',
                           13: 'Italia', 14: 'Suiza', 15: 'Dinamarca', 16: 'Zambia',
                           17: 'Nigeria', 18: 'Panama', 19: 'Canada', 20: 'Marruecos',
                            21: 'Portugal', 22: 'China', 23: 'Argentina', 24: 'Nueva Zelanda',
                           25: 'Jamaica', 26: 'Irlanda', 27: 'Corea del Sur', 28: 'Filipinas',
                           29: 'Costa Rica', 30: 'Haiti', 31: 'Vietnam'})

# %%
data = data.drop(data.index[0])

data
# Out:
#                     España Japon Holanda Francia Australia Suecia Inglaterra  \
# 2023-07-20 00:00:00      0     0       0       0         1      0          0
# 2023-07-21 00:00:00      1     0       0       0         1      0          0
# 2023-07-22 00:00:00      1     1       0       0         1      0          1
# 2023-07-23 00:00:00      1     1       1       0         1      1          1
# 2023-07-24 00:00:00      1     1       1       0         1      1          1
# 2023-07-25 00:00:00      1     1       1       0         1      1          1
# 2023-07-26 00:00:00      2     2       1       0         1      1          1
# 2023-07-27 00:00:00      2     2       1       0         1      1          1
# 2023-07-28 00:00:00      2     2       1       0         1      1          2
# 2023-07-29 00:00:00      2     2       1       1         1      2          2
# 2023-07-30 00:00:00      2     2       1       1         1      2          2
# ...

# %%
data = data.apply(pd.to_numeric, errors='coerce')

data
# Out:
#             España  Japon  Holanda  Francia  Australia  Suecia  Inglaterra  \
# 2023-07-20       0      0        0        0          1       0           0
# 2023-07-21       1      0        0        0          1       0           0
# 2023-07-22       1      1        0        0          1       0           1
# 2023-07-23       1      1        1        0          1       1           1
# 2023-07-24       1      1        1        0          1       1           1
# 2023-07-25       1      1        1        0          1       1           1
# 2023-07-26       2      2        1        0          1       1           1
# 2023-07-27       2      2        1        0          1       1           1
# 2023-07-28       2      2        1        0          1       1           2
# 2023-07-29       2      2        1        1          1       2           2
# 2023-07-30       2      2        1        1          1       2           2
# ...

# %%
bcr.bar_chart_race(df=data)
# Out:
# <video width="956" height="504" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
bcr.bar_chart_race(df=data, filename='C:\\Users\\delbr\\Desktop\\Proyectos IronHack\\PROYECTO_FINAL\\Evolucion_victorias.mp4')
